# %%
pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.7 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.7 MB 1.7 MB/s eta 0:00:08
#    -- ------------------------------------- 0.8/12.7 MB 1.4 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.3/12.7 MB 1.8 MB/s eta 0:00:07
#    ------ --------------------------------- 2.1/12.7 MB 2.2 MB/s eta 0:00:05
#    --------- ------------------------------ 2.9/12.7 MB 2.4 MB/s eta 0:00:05
#    ---------- ----------------------------- 3.4/12.7 MB 2.6 MB/s eta 0:00:04
#    ------------- -------------------------- 4.2/12.7 MB 2.6 MB/s eta 0:00:04
#    -------------- ------------------------- 4.5/12.7 MB 2.6 MB/s eta 0:00:04
#    -------------- ------------------------- 4.7/12.7 MB 2.4 MB/s eta 0:00:04
#    --------------- ------------------------ 5.0/12.7 MB 2.2 MB/s eta 0:00:04
# ...

# %%
import numpy as np

# %%
arr=np.array([21,90,30,'haadi'])
print(arr)
# Out:
# ['21' '90' '30' 'haadi']

# %%
ar=np.array([21,90,20,45,89])
print(ar)
# Out:
# [21 90 20 45 89]

# %%
import numpy as np

# %%
ar2=np.array([[12,90,7],[12,45,11]])

print(ar2.ndim)
# Out:
# 2
